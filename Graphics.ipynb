# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
pd.options.display.float_format = '{:,.5f}'.format

# %%
df=pd.read_csv("output.csv")
Y = list(df.columns)
df = df.rename(columns = {Y[0]:'degree of polynom', Y[1]:'time,ms'}, inplace = False)
Y = list(df.columns)

# %%
df
# Out:
#     degree of polynom  time,ms
# 0                   2  0.00093
# 1                   2  0.00077
# 2                   2  0.00076
# 3                   2  0.00077
# 4                   2  0.00088
# 5                   2  0.00086
# 6                   2  0.00093
# 7                   2  0.00090
# 8                   2  0.00101
# 9                   3  0.01334
# 10                  3  0.00947
# 11                  3  0.00713
# 12                  3  0.00800
# 13                  3  0.00875
# 14                  3  0.00981
# 15                  3  0.00679
# 16                  3  0.00654
# 17                  3  0.00634
# 18                  3  0.00713
# 19                  4  0.23835
# 20                  4  0.22674
# 21                  4  0.23235
# 22                  4  0.22332
# 23                  4  0.37788
# 24                  4  0.37608
# 25                  4  0.38669
# 26                  4  0.39184
# 27                  4  0.37773
# 28                  4  0.38838

# %%
df.plot(kind = 'scatter',x=Y[0],y=Y[1])
plt.savefig("3pol(2).png")
